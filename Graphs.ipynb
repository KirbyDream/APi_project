# %%
import import_ipynb

# %%
import cleaning_VG
# Out:
# importing Jupyter notebook from cleaning_VG.ipynb
# Index(['Name', 'Platform', 'Year', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales'],
#       dtype='object')
# Traceback (most recent call last):
#
#   File ~\miniconda3\lib\site-packages\IPython\core\interactiveshell.py:3397 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Input In [3] in <cell line: 1>
#     import cleaning_VG
#
#   File <frozen importlib._bootstrap>:1007 in _find_and_load
#
#   File <frozen importlib._bootstrap>:986 in _find_and_load_unlocked
#
#   File <frozen importlib._bootstrap>:664 in _load_unlocked
#
#   File <frozen importlib._bootstrap>:627 in _load_backward_compatible
#
#   File ~\miniconda3\lib\site-packages\import_ipynb.py:61 in load_module
#     exec(code, mod.__dict__)
#
#   File <string>:1
# ...
